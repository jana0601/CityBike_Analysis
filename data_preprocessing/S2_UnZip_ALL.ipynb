# %%
import os
import zipfile
import glob
import re
import shutil

import os
import zipfile
import shutil

def extract_zip_to_same_folder(zip_path,extract_dir):
    """Extract ZIP file in the same folder, excluding __MACOSX."""
    #extract_dir = os.path.dirname(zip_path)
    try:
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            for file in zip_ref.namelist():
                if '__MACOSX' not in file and not file.endswith('/'):
                    zip_ref.extract(file, extract_dir)
        print(f"✅ Extracted: {zip_path}")
    except zipfile.BadZipFile:
        print(f"❌ Invalid ZIP file: {zip_path}")

def find_all_csvs(folder_path, extract_dir):
    """
    Recursively find all CSV files in a folder.
    If any ZIPs are found, they will be extracted first (recursively).
    Skips __MACOSX folders.
    """
    csv_files = []

    for root, dirs, files in os.walk(folder_path):
        # Skip __MACOSX
        if '__MACOSX' in root:
            continue

        for file in files:
            full_path = os.path.join(root, file)

            if file.lower().endswith('.zip'):
                # Extract ZIP and process its contents
                extract_zip_to_same_folder(full_path, extract_dir)
                # Optional: delete ZIP after extracting
                os.remove(full_path)
            elif file.lower().endswith('.csv'):
                csv_files.append(full_path)

    # After extracting all ZIPs, do one more sweep to find any new CSVs
    for root, dirs, files in os.walk(folder_path):
        if '__MACOSX' in root:
            continue
        for file in files:
            if file.lower().endswith('.csv'):
                full_path = os.path.join(root, file)
                if full_path not in csv_files:
                    csv_files.append(full_path)

    return csv_files



# Folder containing ZIP files
zip_folder = "..//tripdata_zips"

# Base output folder
base_output_folder = "..//extracted_tripdata4"
os.makedirs(base_output_folder, exist_ok=True)

# Regex to extract years from 2013 to 2025
year_pattern = re.compile(r"(201[3-9]|202[0-5])")

# Get all ZIP files in the folder
zip_files = glob.glob(os.path.join(zip_folder, "*.zip"))

for zip_file in zip_files:
    base_name = os.path.basename(zip_file)

    # Extract year from filename
    match = year_pattern.search(base_name)
    if not match:
        print(f"No valid year found in {base_name}, skipping.")
        continue
    year = match.group(0)

    # Create year output folder
    year_folder = os.path.join(base_output_folder, year)
    os.makedirs(year_folder, exist_ok=True)

    # Extract all contents to year folder
    extract_zip_to_same_folder(zip_file, extract_dir=year_folder)

    # Find all CSVs inside the extracted content
    csv_files = find_all_csvs(year_folder, extract_dir=year_folder )
    print(f"  → Found {len(csv_files)} CSV file(s) in {year_folder}")

    # Optional: move all CSVs to year folder (flatten structure)
    for csv_path in csv_files:
        filename = os.path.basename(csv_path)
        new_path = os.path.join(year_folder, filename)

        # Avoid overwriting files with same name
        if os.path.abspath(csv_path) != os.path.abspath(new_path):
            shutil.move(csv_path, new_path)
            print(f"    Moved {csv_path} → {new_path}")
# Out:
# ✅ Extracted: ..//tripdata_zips\2013-citibike-tripdata.zip
#   → Found 34 CSV file(s) in ..//extracted_tripdata4\2013
#     Moved ..//extracted_tripdata4\2013\2013-citibike-tripdata\201306-citibike-tripdata.csv → ..//extracted_tripdata4\2013\201306-citibike-tripdata.csv
#     Moved ..//extracted_tripdata4\2013\2013-citibike-tripdata\201307-citibike-tripdata.csv → ..//extracted_tripdata4\2013\201307-citibike-tripdata.csv
#     Moved ..//extracted_tripdata4\2019\2019-citibike-tripdata\7_July\201907-citibike-tripdata_3.csv → ..//extracted_tripdata4\2019\201907-citibike-tripdata_3.csv
#     Moved ..//extracted_tripdata4\2019\2019-citibike-tripdata\8_August\201908-citibike-tripdata_1.csv → ..//extracted_tripdata4\2019\201908-citibike-tripdata_1.csv
#     Moved ..//extracted_tripdata4\2019\2019-citibike-tripdata\8_August\201908-citibike-tripdata_2.csv → ..//extracted_tripdata4\2019\201908-citibike-tripdata_2.csv
#     Moved ..//extracted_tripdata4\2019\2019-citibike-tripdata\8_August\201908-citibike-tripdata_3.csv → ..//extracted_tripdata4\2019\201908-citibike-tripdata_3.csv
#     Moved ..//extracted_tripdata4\2019\2019-citibike-tripdata\9_September\201909-citibike-tripdata_1.csv → ..//extracted_tripdata4\2019\201909-citibike-tripdata_1.csv
#     Moved ..//extracted_tripdata4\2019\2019-citibike-tripdata\9_September\201909-citibike-tripdata_2.csv → ..//extracted_tripdata4\2019\201909-citibike-tripdata_2.csv
#     Moved ..//extracted_tripdata4\2019\2019-citibike-tripdata\9_September\201909-citibike-tripdata_3.csv → ..//extracted_tripdata4\2019\201909-citibike-tripdata_3.csv
# ✅ Extracted: ..//tripdata_zips\2020-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2020\2020-citibike-tripdata\202001-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2020\2020-citibike-tripdata\202002-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2020\2020-citibike-tripdata\202003-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2020\2020-citibike-tripdata\202004-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2020\2020-citibike-tripdata\202005-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2020\2020-citibike-tripdata\202006-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2020\2020-citibike-tripdata\202007-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2020\2020-citibike-tripdata\202008-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2020\2020-citibike-tripdata\202009-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2020\2020-citibike-tripdata\202010-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2020\2020-citibike-tripdata\202011-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2020\2020-citibike-tripdata\202012-citibike-tripdata.zip
#   → Found 27 CSV file(s) in ..//extracted_tripdata4\2020
# ✅ Extracted: ..//tripdata_zips\2021-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2021\2021-citibike-tripdata\202101-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2021\2021-citibike-tripdata\202102-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2021\2021-citibike-tripdata\202103-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2021\2021-citibike-tripdata\202104-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2021\2021-citibike-tripdata\202105-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2021\2021-citibike-tripdata\202106-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2021\2021-citibike-tripdata\202107-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2021\2021-citibike-tripdata\202108-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2021\2021-citibike-tripdata\202109-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2021\2021-citibike-tripdata\202110-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2021\2021-citibike-tripdata\202111-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2021\2021-citibike-tripdata\202112-citibike-tripdata.zip
#   → Found 36 CSV file(s) in ..//extracted_tripdata4\2021
# ✅ Extracted: ..//tripdata_zips\2022-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2022\2022-citibike-tripdata\202201-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2022\2022-citibike-tripdata\202202-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2022\2022-citibike-tripdata\202203-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2022\2022-citibike-tripdata\202204-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2022\2022-citibike-tripdata\202205-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2022\2022-citibike-tripdata\202206-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2022\2022-citibike-tripdata\202207-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2022\2022-citibike-tripdata\202208-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2022\2022-citibike-tripdata\202209-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2022\2022-citibike-tripdata\202210-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2022\2022-citibike-tripdata\202211-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2022\2022-citibike-tripdata\202212-citibike-tripdata.zip
#   → Found 36 CSV file(s) in ..//extracted_tripdata4\2022
# ✅ Extracted: ..//tripdata_zips\2023-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2023\2023-citibike-tripdata\202301-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2023\2023-citibike-tripdata\202302-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2023\2023-citibike-tripdata\202303-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2023\2023-citibike-tripdata\202304-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2023\2023-citibike-tripdata\202305-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2023\2023-citibike-tripdata\202306-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2023\2023-citibike-tripdata\202307-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2023\2023-citibike-tripdata\202308-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2023\2023-citibike-tripdata\202309-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2023\2023-citibike-tripdata\202310-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2023\2023-citibike-tripdata\202311-citibike-tripdata.zip
# ✅ Extracted: ..//extracted_tripdata4\2023\2023-citibike-tripdata\202312-citibike-tripdata.zip
#   → Found 40 CSV file(s) in ..//extracted_tripdata4\2023
# ✅ Extracted: ..//tripdata_zips\202401-citibike-tripdata.zip
#   → Found 47 CSV file(s) in ..//extracted_tripdata4\2024
# ✅ Extracted: ..//tripdata_zips\202402-citibike-tripdata.zip
#   → Found 47 CSV file(s) in ..//extracted_tripdata4\2024
# ✅ Extracted: ..//tripdata_zips\202403-citibike-tripdata.zip
#   → Found 47 CSV file(s) in ..//extracted_tripdata4\2024
# ✅ Extracted: ..//tripdata_zips\202404-citibike-tripdata.zip
#   → Found 47 CSV file(s) in ..//extracted_tripdata4\2024
# ✅ Extracted: ..//tripdata_zips\202405-citibike-tripdata.zip
#   → Found 47 CSV file(s) in ..//extracted_tripdata4\2024
# ✅ Extracted: ..//tripdata_zips\202406-citibike-tripdata.zip
#   → Found 47 CSV file(s) in ..//extracted_tripdata4\2024
# ✅ Extracted: ..//tripdata_zips\202407-citibike-tripdata.zip
#   → Found 47 CSV file(s) in ..//extracted_tripdata4\2024
# ✅ Extracted: ..//tripdata_zips\202408-citibike-tripdata.zip
#   → Found 47 CSV file(s) in ..//extracted_tripdata4\2024
# ✅ Extracted: ..//tripdata_zips\202409-citibike-tripdata.zip
#   → Found 47 CSV file(s) in ..//extracted_tripdata4\2024
# ✅ Extracted: ..//tripdata_zips\202410-citibike-tripdata.zip
#   → Found 47 CSV file(s) in ..//extracted_tripdata4\2024
# ✅ Extracted: ..//tripdata_zips\202411-citibike-tripdata.zip
#   → Found 47 CSV file(s) in ..//extracted_tripdata4\2024
# ✅ Extracted: ..//tripdata_zips\202412-citibike-tripdata.zip
#   → Found 50 CSV file(s) in ..//extracted_tripdata4\2024
# ✅ Extracted: ..//tripdata_zips\202501-citibike-tripdata.zip
#   → Found 3 CSV file(s) in ..//extracted_tripdata4\2025
# ✅ Extracted: ..//tripdata_zips\202502-citibike-tripdata.zip
#   → Found 6 CSV file(s) in ..//extracted_tripdata4\2025
# ✅ Extracted: ..//tripdata_zips\202503-citibike-tripdata.zip
#   → Found 10 CSV file(s) in ..//extracted_tripdata4\2025
# ✅ Extracted: ..//tripdata_zips\202504-citibike-tripdata.zip
#   → Found 14 CSV file(s) in ..//extracted_tripdata4\2025
# ✅ Extracted: ..//tripdata_zips\202505-citibike-tripdata.zip
#   → Found 19 CSV file(s) in ..//extracted_tripdata4\2025
# ✅ Extracted: ..//tripdata_zips\202506-citibike-tripdata.zip
#   → Found 24 CSV file(s) in ..//extracted_tripdata4\2025
# ✅ Extracted: ..//tripdata_zips\202507-citibike-tripdata.zip
#   → Found 29 CSV file(s) in ..//extracted_tripdata4\2025
# ✅ Extracted: ..//tripdata_zips\202508-citibike-tripdata.zip
#   → Found 35 CSV file(s) in ..//extracted_tripdata4\2025
# ✅ Extracted: ..//tripdata_zips\202509-citibike-tripdata.zip
#   → Found 41 CSV file(s) in ..//extracted_tripdata4\2025
# ✅ Extracted: ..//tripdata_zips\JC-201509-citibike-tripdata.csv.zip
#   → Found 17 CSV file(s) in ..//extracted_tripdata4\2015
# ✅ Extracted: ..//tripdata_zips\JC-201510-citibike-tripdata.csv.zip
#   → Found 18 CSV file(s) in ..//extracted_tripdata4\2015
# ✅ Extracted: ..//tripdata_zips\JC-201511-citibike-tripdata.csv.zip
#   → Found 19 CSV file(s) in ..//extracted_tripdata4\2015
# ✅ Extracted: ..//tripdata_zips\JC-201512-citibike-tripdata.csv.zip
#   → Found 20 CSV file(s) in ..//extracted_tripdata4\2015
# ✅ Extracted: ..//tripdata_zips\JC-201601-citibike-tripdata.csv.zip
#   → Found 21 CSV file(s) in ..//extracted_tripdata4\2016
# ✅ Extracted: ..//tripdata_zips\JC-201602-citibike-tripdata.csv.zip
#   → Found 22 CSV file(s) in ..//extracted_tripdata4\2016
# ✅ Extracted: ..//tripdata_zips\JC-201603-citibike-tripdata.csv.zip
#   → Found 23 CSV file(s) in ..//extracted_tripdata4\2016
# ✅ Extracted: ..//tripdata_zips\JC-201604-citibike-tripdata.csv.zip
#   → Found 24 CSV file(s) in ..//extracted_tripdata4\2016
# ✅ Extracted: ..//tripdata_zips\JC-201605-citibike-tripdata.csv.zip
#   → Found 25 CSV file(s) in ..//extracted_tripdata4\2016
# ✅ Extracted: ..//tripdata_zips\JC-201606-citibike-tripdata.csv.zip
#   → Found 26 CSV file(s) in ..//extracted_tripdata4\2016
# ✅ Extracted: ..//tripdata_zips\JC-201607-citibike-tripdata.csv.zip
#   → Found 27 CSV file(s) in ..//extracted_tripdata4\2016
# ✅ Extracted: ..//tripdata_zips\JC-201608-citibike-tripdata.csv.zip
#   → Found 28 CSV file(s) in ..//extracted_tripdata4\2016
# ✅ Extracted: ..//tripdata_zips\JC-201609-citibike-tripdata.csv.zip
#   → Found 29 CSV file(s) in ..//extracted_tripdata4\2016
# ✅ Extracted: ..//tripdata_zips\JC-201610-citibike-tripdata.csv.zip
#   → Found 30 CSV file(s) in ..//extracted_tripdata4\2016
# ✅ Extracted: ..//tripdata_zips\JC-201611-citibike-tripdata.csv.zip
#   → Found 31 CSV file(s) in ..//extracted_tripdata4\2016
# ✅ Extracted: ..//tripdata_zips\JC-201612-citibike-tripdata.csv.zip
#   → Found 32 CSV file(s) in ..//extracted_tripdata4\2016
# ✅ Extracted: ..//tripdata_zips\JC-201701-citibike-tripdata.csv.zip
#   → Found 21 CSV file(s) in ..//extracted_tripdata4\2017
# ✅ Extracted: ..//tripdata_zips\JC-201702-citibike-tripdata.csv.zip
#   → Found 22 CSV file(s) in ..//extracted_tripdata4\2017
# ✅ Extracted: ..//tripdata_zips\JC-201703-citibike-tripdata.csv.zip
#   → Found 23 CSV file(s) in ..//extracted_tripdata4\2017
# ✅ Extracted: ..//tripdata_zips\JC-201704-citibike-tripdata.csv.zip
#   → Found 24 CSV file(s) in ..//extracted_tripdata4\2017
# ✅ Extracted: ..//tripdata_zips\JC-201705-citibike-tripdata.csv.zip
#   → Found 25 CSV file(s) in ..//extracted_tripdata4\2017
# ✅ Extracted: ..//tripdata_zips\JC-201706-citibike-tripdata.csv.zip
#   → Found 26 CSV file(s) in ..//extracted_tripdata4\2017
# ✅ Extracted: ..//tripdata_zips\JC-201707-citibike-tripdata.csv.zip
#   → Found 27 CSV file(s) in ..//extracted_tripdata4\2017
# ✅ Extracted: ..//tripdata_zips\JC-201708 citibike-tripdata.csv.zip
#   → Found 28 CSV file(s) in ..//extracted_tripdata4\2017
# ✅ Extracted: ..//tripdata_zips\JC-201709-citibike-tripdata.csv.zip
#   → Found 29 CSV file(s) in ..//extracted_tripdata4\2017
# ✅ Extracted: ..//tripdata_zips\JC-201710-citibike-tripdata.csv.zip
#   → Found 30 CSV file(s) in ..//extracted_tripdata4\2017
# ✅ Extracted: ..//tripdata_zips\JC-201711-citibike-tripdata.csv.zip
#   → Found 31 CSV file(s) in ..//extracted_tripdata4\2017
# ✅ Extracted: ..//tripdata_zips\JC-201712-citibike-tripdata.csv.zip
#   → Found 32 CSV file(s) in ..//extracted_tripdata4\2017
# ✅ Extracted: ..//tripdata_zips\JC-201801-citibike-tripdata.csv.zip
#   → Found 34 CSV file(s) in ..//extracted_tripdata4\2018
# ✅ Extracted: ..//tripdata_zips\JC-201802-citibike-tripdata.csv.zip
#   → Found 35 CSV file(s) in ..//extracted_tripdata4\2018
# ✅ Extracted: ..//tripdata_zips\JC-201803-citibike-tripdata.csv.zip
#   → Found 36 CSV file(s) in ..//extracted_tripdata4\2018
# ✅ Extracted: ..//tripdata_zips\JC-201804-citibike-tripdata.csv.zip
#   → Found 37 CSV file(s) in ..//extracted_tripdata4\2018
# ✅ Extracted: ..//tripdata_zips\JC-201805-citibike-tripdata.csv.zip
#   → Found 38 CSV file(s) in ..//extracted_tripdata4\2018
# ✅ Extracted: ..//tripdata_zips\JC-201806-citibike-tripdata.csv.zip
#   → Found 39 CSV file(s) in ..//extracted_tripdata4\2018
# ✅ Extracted: ..//tripdata_zips\JC-201807-citibike-tripdata.csv.zip
#   → Found 40 CSV file(s) in ..//extracted_tripdata4\2018
# ✅ Extracted: ..//tripdata_zips\JC-201808-citibike-tripdata.csv.zip
#   → Found 41 CSV file(s) in ..//extracted_tripdata4\2018
# ✅ Extracted: ..//tripdata_zips\JC-201809-citibike-tripdata.csv.zip
#   → Found 42 CSV file(s) in ..//extracted_tripdata4\2018
# ✅ Extracted: ..//tripdata_zips\JC-201810-citibike-tripdata.csv.zip
#   → Found 43 CSV file(s) in ..//extracted_tripdata4\2018
# ✅ Extracted: ..//tripdata_zips\JC-201811-citibike-tripdata.csv.zip
#   → Found 44 CSV file(s) in ..//extracted_tripdata4\2018
# ✅ Extracted: ..//tripdata_zips\JC-201812-citibike-tripdata.csv.zip
#   → Found 45 CSV file(s) in ..//extracted_tripdata4\2018
# ✅ Extracted: ..//tripdata_zips\JC-201901-citibike-tripdata.csv.zip
#   → Found 27 CSV file(s) in ..//extracted_tripdata4\2019
# ✅ Extracted: ..//tripdata_zips\JC-201902-citibike-tripdata.csv.zip
#   → Found 28 CSV file(s) in ..//extracted_tripdata4\2019
# ✅ Extracted: ..//tripdata_zips\JC-201903-citibike-tripdata.csv.zip
#   → Found 29 CSV file(s) in ..//extracted_tripdata4\2019
# ✅ Extracted: ..//tripdata_zips\JC-201904-citibike-tripdata.csv.zip
#   → Found 30 CSV file(s) in ..//extracted_tripdata4\2019
# ✅ Extracted: ..//tripdata_zips\JC-201905-citibike-tripdata.csv.zip
#   → Found 31 CSV file(s) in ..//extracted_tripdata4\2019
# ✅ Extracted: ..//tripdata_zips\JC-201906-citibike-tripdata.csv.zip
#   → Found 32 CSV file(s) in ..//extracted_tripdata4\2019
# ✅ Extracted: ..//tripdata_zips\JC-201907-citibike-tripdata.csv.zip
#   → Found 33 CSV file(s) in ..//extracted_tripdata4\2019
# ✅ Extracted: ..//tripdata_zips\JC-201908-citibike-tripdata.csv.zip
#   → Found 34 CSV file(s) in ..//extracted_tripdata4\2019
# ✅ Extracted: ..//tripdata_zips\JC-201909-citibike-tripdata.csv.zip
#   → Found 35 CSV file(s) in ..//extracted_tripdata4\2019
# ✅ Extracted: ..//tripdata_zips\JC-201910-citibike-tripdata.csv.zip
#   → Found 36 CSV file(s) in ..//extracted_tripdata4\2019
# ✅ Extracted: ..//tripdata_zips\JC-201911-citibike-tripdata.csv.zip
#   → Found 37 CSV file(s) in ..//extracted_tripdata4\2019
# ✅ Extracted: ..//tripdata_zips\JC-201912-citibike-tripdata.csv.zip
#   → Found 38 CSV file(s) in ..//extracted_tripdata4\2019
# ✅ Extracted: ..//tripdata_zips\JC-202001-citibike-tripdata.csv.zip
#   → Found 28 CSV file(s) in ..//extracted_tripdata4\2020
# ✅ Extracted: ..//tripdata_zips\JC-202002-citibike-tripdata.csv.zip
#   → Found 29 CSV file(s) in ..//extracted_tripdata4\2020
# ✅ Extracted: ..//tripdata_zips\JC-202003-citibike-tripdata.csv.zip
#   → Found 30 CSV file(s) in ..//extracted_tripdata4\2020
# ✅ Extracted: ..//tripdata_zips\JC-202004-citibike-tripdata.csv.zip
#   → Found 31 CSV file(s) in ..//extracted_tripdata4\2020
# ✅ Extracted: ..//tripdata_zips\JC-202005-citibike-tripdata.csv.zip
#   → Found 32 CSV file(s) in ..//extracted_tripdata4\2020
# ✅ Extracted: ..//tripdata_zips\JC-202006-citibike-tripdata.csv.zip
#   → Found 33 CSV file(s) in ..//extracted_tripdata4\2020
# ✅ Extracted: ..//tripdata_zips\JC-202007-citibike-tripdata.csv.zip
#   → Found 34 CSV file(s) in ..//extracted_tripdata4\2020
# ✅ Extracted: ..//tripdata_zips\JC-202008-citibike-tripdata.csv.zip
#   → Found 35 CSV file(s) in ..//extracted_tripdata4\2020
# ✅ Extracted: ..//tripdata_zips\JC-202009-citibike-tripdata.csv.zip
#   → Found 36 CSV file(s) in ..//extracted_tripdata4\2020
# ✅ Extracted: ..//tripdata_zips\JC-202010-citibike-tripdata.csv.zip
#   → Found 37 CSV file(s) in ..//extracted_tripdata4\2020
# ✅ Extracted: ..//tripdata_zips\JC-202011-citibike-tripdata.csv.zip
#   → Found 38 CSV file(s) in ..//extracted_tripdata4\2020
# ✅ Extracted: ..//tripdata_zips\JC-202012-citibike-tripdata.csv.zip
#   → Found 39 CSV file(s) in ..//extracted_tripdata4\2020
# ✅ Extracted: ..//tripdata_zips\JC-202101-citibike-tripdata.csv.zip
#   → Found 37 CSV file(s) in ..//extracted_tripdata4\2021
# ✅ Extracted: ..//tripdata_zips\JC-202102-citibike-tripdata.csv.zip
#   → Found 38 CSV file(s) in ..//extracted_tripdata4\2021
# ✅ Extracted: ..//tripdata_zips\JC-202103-citibike-tripdata.csv.zip
#   → Found 39 CSV file(s) in ..//extracted_tripdata4\2021
# ✅ Extracted: ..//tripdata_zips\JC-202104-citibike-tripdata.csv.zip
#   → Found 40 CSV file(s) in ..//extracted_tripdata4\2021
# ✅ Extracted: ..//tripdata_zips\JC-202105-citibike-tripdata.csv.zip
#   → Found 41 CSV file(s) in ..//extracted_tripdata4\2021
# ✅ Extracted: ..//tripdata_zips\JC-202106-citibike-tripdata.csv.zip
#   → Found 42 CSV file(s) in ..//extracted_tripdata4\2021
# ✅ Extracted: ..//tripdata_zips\JC-202107-citibike-tripdata.csv.zip
#   → Found 43 CSV file(s) in ..//extracted_tripdata4\2021
# ✅ Extracted: ..//tripdata_zips\JC-202108-citibike-tripdata.csv.zip
#   → Found 44 CSV file(s) in ..//extracted_tripdata4\2021
# ✅ Extracted: ..//tripdata_zips\JC-202109-citibike-tripdata.csv.zip
#   → Found 45 CSV file(s) in ..//extracted_tripdata4\2021
# ✅ Extracted: ..//tripdata_zips\JC-202110-citibike-tripdata.csv.zip
#   → Found 46 CSV file(s) in ..//extracted_tripdata4\2021
# ✅ Extracted: ..//tripdata_zips\JC-202111-citibike-tripdata.csv.zip
#   → Found 47 CSV file(s) in ..//extracted_tripdata4\2021
# ✅ Extracted: ..//tripdata_zips\JC-202112-citibike-tripdata.csv.zip
#   → Found 48 CSV file(s) in ..//extracted_tripdata4\2021
# ✅ Extracted: ..//tripdata_zips\JC-202201-citibike-tripdata.csv.zip
#   → Found 37 CSV file(s) in ..//extracted_tripdata4\2022
# ✅ Extracted: ..//tripdata_zips\JC-202202-citibike-tripdata.csv.zip
#   → Found 38 CSV file(s) in ..//extracted_tripdata4\2022
# ✅ Extracted: ..//tripdata_zips\JC-202203-citibike-tripdata.csv.zip
#   → Found 39 CSV file(s) in ..//extracted_tripdata4\2022
# ✅ Extracted: ..//tripdata_zips\JC-202204-citibike-tripdata.csv.zip
#   → Found 40 CSV file(s) in ..//extracted_tripdata4\2022
# ✅ Extracted: ..//tripdata_zips\JC-202205-citibike-tripdata.csv.zip
#   → Found 41 CSV file(s) in ..//extracted_tripdata4\2022
# ✅ Extracted: ..//tripdata_zips\JC-202206-citibike-tripdata.csv.zip
#   → Found 42 CSV file(s) in ..//extracted_tripdata4\2022
# ✅ Extracted: ..//tripdata_zips\JC-202207-citbike-tripdata.csv.zip
#   → Found 43 CSV file(s) in ..//extracted_tripdata4\2022
# ✅ Extracted: ..//tripdata_zips\JC-202208-citibike-tripdata.csv.zip
#   → Found 44 CSV file(s) in ..//extracted_tripdata4\2022
# ✅ Extracted: ..//tripdata_zips\JC-202209-citibike-tripdata.csv.zip
#   → Found 45 CSV file(s) in ..//extracted_tripdata4\2022
# ✅ Extracted: ..//tripdata_zips\JC-202210-citibike-tripdata.csv.zip
#   → Found 46 CSV file(s) in ..//extracted_tripdata4\2022
# ✅ Extracted: ..//tripdata_zips\JC-202211-citibike-tripdata.csv.zip
#   → Found 47 CSV file(s) in ..//extracted_tripdata4\2022
# ✅ Extracted: ..//tripdata_zips\JC-202212-citibike-tripdata.csv.zip
#   → Found 48 CSV file(s) in ..//extracted_tripdata4\2022
# ✅ Extracted: ..//tripdata_zips\JC-202301-citibike-tripdata.csv.zip
#   → Found 41 CSV file(s) in ..//extracted_tripdata4\2023
# ✅ Extracted: ..//tripdata_zips\JC-202302-citibike-tripdata.csv.zip
#   → Found 42 CSV file(s) in ..//extracted_tripdata4\2023
# ✅ Extracted: ..//tripdata_zips\JC-202303-citibike-tripdata.csv.zip
#   → Found 43 CSV file(s) in ..//extracted_tripdata4\2023
# ✅ Extracted: ..//tripdata_zips\JC-202304-citibike-tripdata.csv.zip
#   → Found 44 CSV file(s) in ..//extracted_tripdata4\2023
# ✅ Extracted: ..//tripdata_zips\JC-202305-citibike-tripdata.csv.zip
#   → Found 45 CSV file(s) in ..//extracted_tripdata4\2023
# ✅ Extracted: ..//tripdata_zips\JC-202306-citibike-tripdata.csv.zip
#   → Found 46 CSV file(s) in ..//extracted_tripdata4\2023
# ✅ Extracted: ..//tripdata_zips\JC-202307-citibike-tripdata.csv.zip
#   → Found 47 CSV file(s) in ..//extracted_tripdata4\2023
# ✅ Extracted: ..//tripdata_zips\JC-202308-citibike-tripdata.csv.zip
#   → Found 48 CSV file(s) in ..//extracted_tripdata4\2023
# ✅ Extracted: ..//tripdata_zips\JC-202309-citibike-tripdata.csv.zip
#   → Found 49 CSV file(s) in ..//extracted_tripdata4\2023
# ✅ Extracted: ..//tripdata_zips\JC-202310-citibike-tripdata.csv.zip
#   → Found 50 CSV file(s) in ..//extracted_tripdata4\2023
# ✅ Extracted: ..//tripdata_zips\JC-202311-citibike-tripdata.csv.zip
#   → Found 51 CSV file(s) in ..//extracted_tripdata4\2023
# ✅ Extracted: ..//tripdata_zips\JC-202312-citibike-tripdata.csv.zip
#   → Found 52 CSV file(s) in ..//extracted_tripdata4\2023
# ✅ Extracted: ..//tripdata_zips\JC-202401-citibike-tripdata.csv.zip
#   → Found 51 CSV file(s) in ..//extracted_tripdata4\2024
# ✅ Extracted: ..//tripdata_zips\JC-202402-citibike-tripdata.csv.zip
#   → Found 52 CSV file(s) in ..//extracted_tripdata4\2024
# ✅ Extracted: ..//tripdata_zips\JC-202403-citibike-tripdata.csv.zip
#   → Found 53 CSV file(s) in ..//extracted_tripdata4\2024
# ✅ Extracted: ..//tripdata_zips\JC-202404-citibike-tripdata.csv.zip
#   → Found 54 CSV file(s) in ..//extracted_tripdata4\2024
# ✅ Extracted: ..//tripdata_zips\JC-202405-citibike-tripdata.csv.zip
#   → Found 55 CSV file(s) in ..//extracted_tripdata4\2024
# ✅ Extracted: ..//tripdata_zips\JC-202406-citibike-tripdata.csv.zip
#   → Found 56 CSV file(s) in ..//extracted_tripdata4\2024
# ✅ Extracted: ..//tripdata_zips\JC-202407-citibike-tripdata.csv.zip
#   → Found 57 CSV file(s) in ..//extracted_tripdata4\2024
# ✅ Extracted: ..//tripdata_zips\JC-202408-citibike-tripdata.csv.zip
#   → Found 58 CSV file(s) in ..//extracted_tripdata4\2024
# ✅ Extracted: ..//tripdata_zips\JC-202409-citibike-tripdata.csv.zip
#   → Found 59 CSV file(s) in ..//extracted_tripdata4\2024
# ✅ Extracted: ..//tripdata_zips\JC-202410-citibike-tripdata.csv.zip
#   → Found 60 CSV file(s) in ..//extracted_tripdata4\2024
# ✅ Extracted: ..//tripdata_zips\JC-202411-citibike-tripdata.csv.zip
#   → Found 61 CSV file(s) in ..//extracted_tripdata4\2024
# ✅ Extracted: ..//tripdata_zips\JC-202412-citibike-tripdata.csv.zip
#   → Found 62 CSV file(s) in ..//extracted_tripdata4\2024
# ✅ Extracted: ..//tripdata_zips\JC-202501-citibike-tripdata.csv.zip
#   → Found 42 CSV file(s) in ..//extracted_tripdata4\2025
# ✅ Extracted: ..//tripdata_zips\JC-202502-citibike-tripdata.csv.zip
#   → Found 43 CSV file(s) in ..//extracted_tripdata4\2025
# ✅ Extracted: ..//tripdata_zips\JC-202503-citibike-tripdata.csv.zip
#   → Found 44 CSV file(s) in ..//extracted_tripdata4\2025
# ✅ Extracted: ..//tripdata_zips\JC-202504-citibike-tripdata.csv.zip
#   → Found 45 CSV file(s) in ..//extracted_tripdata4\2025
# ✅ Extracted: ..//tripdata_zips\JC-202505-citibike-tripdata.csv.zip
#   → Found 46 CSV file(s) in ..//extracted_tripdata4\2025
# ✅ Extracted: ..//tripdata_zips\JC-202506-citibike-tripdata.csv.zip
#   → Found 47 CSV file(s) in ..//extracted_tripdata4\2025
# ✅ Extracted: ..//tripdata_zips\JC-202507-citibike-tripdata.csv.zip
#   → Found 48 CSV file(s) in ..//extracted_tripdata4\2025
# ✅ Extracted: ..//tripdata_zips\JC-202508-citibike-tripdata.csv.zip
#   → Found 49 CSV file(s) in ..//extracted_tripdata4\2025
# ✅ Extracted: ..//tripdata_zips\JC-202509-citibike-tripdata.csv.zip
#   → Found 50 CSV file(s) in ..//extracted_tripdata4\2025
