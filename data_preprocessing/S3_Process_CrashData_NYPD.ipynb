# %%
import pandas as pd
accident_path = r"..\accident_data\Motor_Vehicle_Collisions_-_Crashes_20251009.csv"

# Load full CSV, combine date and time into one datetime column while reading
accident_df = pd.read_csv(
    accident_path,
    parse_dates=[['CRASH DATE', 'CRASH TIME']]
)

accident_df.head(20)
# Out:
# C:\Users\yanhu\AppData\Local\Temp\ipykernel_30928\1739564246.py:5: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   accident_df = pd.read_csv(
#    CRASH DATE_CRASH TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0    2021-09-11 02:39:00        NaN      NaN        NaN        NaN
# 1    2022-03-26 11:45:00        NaN      NaN        NaN        NaN
# 2    2023-11-01 01:29:00   BROOKLYN  11230.0  40.621790 -73.970024
# 3    2022-06-29 06:55:00        NaN      NaN        NaN        NaN
# 4    2022-09-21 13:21:00        NaN      NaN        NaN        NaN
# 5    2023-04-26 13:30:00        NaN      NaN        NaN        NaN
# 6    2023-11-01 07:12:00        NaN      NaN        NaN        NaN
# 7    2023-11-01 08:01:00        NaN      NaN        NaN        NaN
# 8    2023-04-26 22:20:00        NaN      NaN        NaN        NaN
# 9    2021-09-11 09:35:00   BROOKLYN  11208.0  40.667202 -73.866500
# ...

# %%
# Rename the combined column
accident_df.rename(columns={'CRASH DATE_CRASH TIME': 'CRASH_DATETIME'}, inplace=True)

# Sort by datetime
accident_df.sort_values('CRASH_DATETIME', inplace=True)

# Reset index after sorting
accident_df.reset_index(drop=True, inplace=True)

# Save sorted data to new CSV
sorted_csv_path = "..//accident_data//sorted_accident_data.csv"  # change path as needed
accident_df.to_csv(sorted_csv_path, index=False)

print(f"Sorted data saved to: {sorted_csv_path}")
# Out:
# Sorted data saved to: ..//accident_data//sorted_accident_data.csv

# %%
# Filter for accidents involving cyclists
sorted_bike_crashes = accident_df[
    (accident_df['NUMBER OF CYCLIST INJURED'] > 0) |
    (accident_df['NUMBER OF CYCLIST KILLED'] > 0)
]
# Save sorted data to new CSV
sorted_csv_path_bike = "..//accident_data//sorted_bike_crashes.csv"  # change path as needed
sorted_bike_crashes.to_csv(sorted_csv_path_bike, index=False)

# %%
sorted_bike_crashes
# Out:
#              CRASH_DATETIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 40      2012-07-01 02:30:00  MANHATTAN    10065  40.764162 -73.968890
# 98      2012-07-01 06:50:00      BRONX    10468  40.862679 -73.909040
# 201     2012-07-01 12:15:00   BROOKLYN    11211  40.711801 -73.942229
# 269     2012-07-01 14:14:00  MANHATTAN    10003  40.731166 -73.991921
# 315     2012-07-01 15:40:00   BROOKLYN    11224  40.576159 -73.989017
# ...                     ...        ...      ...        ...        ...
# 2211416 2025-10-05 17:54:00   BROOKLYN  11206.0  40.699455 -73.939690
# 2211421 2025-10-05 18:50:00   BROOKLYN  11214.0  40.606895 -74.006620
# 2211431 2025-10-05 19:50:00     QUEENS  11354.0  40.759975 -73.829000
# 2211434 2025-10-05 20:15:00   BROOKLYN  11249.0  40.707000 -73.967290
# 2211440 2025-10-05 20:56:00  MANHATTAN  10036.0  40.755806 -73.986404
#
#                           LOCATION                    ON STREET NAME  \
# 40       (40.7641617, -73.9688897)  EAST 61 STREET
# ...
